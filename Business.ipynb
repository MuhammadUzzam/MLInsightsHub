# %% [markdown]
# <div style="display: flex; justify-content: center;">
#     <img src="SparksFoundation.png" alt="SPARKS FOUNDATION">
# </div>

# %% [markdown]
# <h3 style="background-color:#ADD8E6;font-family:newtimeroman;color:blue;text-align:center">Hello, I'm Muhammad Uzzam Siddiqui, currently interning at The Sparks Foundation. I possess a fervent interest in Data Science and Machine Learning and am keen to contribute and expand my knowledge within a dynamic professional setting.
#
#
# I would be honored to connect with you on LinkedIn!
# </h3>

# %% [markdown]
# <h3 style="font-family:newtimeroman;color:white;text-align:center">Dataset Overview</h3>
# <h3 style="color:white;font-family:Lato">Explore the 'SampleSuperstore' dataset, capturing vital information from a fictional superstore. It includes key details like shipping modes, customer segments, sales, quantities, discounts, and profits.</h3>
# <h3 style="font-family:newtimeroman;color:white;text-align:center">Profit-Focused Analysis</h3>
# <h3 style="color:white;font-family:Lato">As a business manager, I'm diving into 'Exploratory Data Analysis' on this dataset to uncover areas for improvement and boost profitability. Stay tuned for insights into critical business challenges and opportunities that may enhance overall profit margins!</h3>

# %% [markdown]
# <h3 style="background-color:#f5f5f5;font-family:newtimeroman;color:#0066cc;text-align:center">IMPORT NECESSARY LIBRARIES</h3>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly as pt
import plotly.express as px
import random
from scipy import stats

# %% [markdown]
# <h1 style="background-color:#FFFFE0;font-family:'Times New Roman', serif;color:#00008B;text-align:center;font-size:60px">EXPLORATORY DATA ANALYSIS</h1>

# %%
store=pd.read_csv('SampleSuperstore.csv')

# %%
store
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
store.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
store.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# <h3 style="background-color:#f5f5f5;font-family:newtimeroman;color:#0066cc;text-align:center">Identifying unique values of some columns</h3>

# %%
store["Segment"].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
store["Country"].unique()
# Out:
# array(['United States'], dtype=object)

# %%
store["Category"].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
store["Sub-Category"].unique()
# Out:
# array(['Bookcases', 'Chairs', 'Labels', 'Tables', 'Storage',
#        'Furnishings', 'Art', 'Phones', 'Binders', 'Appliances', 'Paper',
#        'Accessories', 'Envelopes', 'Fasteners', 'Supplies', 'Machines',
#        'Copiers'], dtype=object)

# %%
store["Region"].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
store["State"].unique()
# Out:
# array(['Kentucky', 'California', 'Florida', 'North Carolina',
#        'Washington', 'Texas', 'Wisconsin', 'Utah', 'Nebraska',
#        'Pennsylvania', 'Illinois', 'Minnesota', 'Michigan', 'Delaware',
#        'Indiana', 'New York', 'Arizona', 'Virginia', 'Tennessee',
#        'Alabama', 'South Carolina', 'Oregon', 'Colorado', 'Iowa', 'Ohio',
#        'Missouri', 'Oklahoma', 'New Mexico', 'Louisiana', 'Connecticut',
#        'New Jersey', 'Massachusetts', 'Georgia', 'Nevada', 'Rhode Island',
#        'Mississippi', 'Arkansas', 'Montana', 'New Hampshire', 'Maryland',
#        'District of Columbia', 'Kansas', 'Vermont', 'Maine',
#        'South Dakota', 'Idaho', 'North Dakota', 'Wyoming',
#        'West Virginia'], dtype=object)

# %%
store["Ship Mode"].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %% [markdown]
# <h2 style="font-family: Arial, sans-serif;background-color:#fafafa; font-size: 40px; font-weight: bold;text-align:center;color:#333;">VISUALIZATIONS USING DIFFERENT PLOTS</h2>

# %% [markdown]
# <h3 style="background-color:#f5f5f5;font-family:newtimeroman;color:#0066cc;text-align:center">
# Sales Analysis by Category, Sub-Category, Region, and Ship Mode using bar chart.</h3>

# %%
# Create the figure and subplots
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize=(12, 10))  
# Plot 1: Sales by Sub-Category
# Group the data by Sub-Category and calculate the sum of Sales
sub_category_data = store.groupby('Sub-Category').sum()
# Sort the data by Sales in descending order
sub_category_data = sub_category_data.sort_values('Sales', ascending=False)
# Define the colormap with increased saturation
colormap = plt.cm.get_cmap('viridis')
colormap = colormap(np.linspace(0, 1, len(sub_category_data)))
colormap[:, 1] = np.clip(colormap[:, 1] + 0.2, 0, 1)  # Increase the saturation 
bars1 = ax1.bar(sub_category_data.index, sub_category_data['Sales'], color=colormap)
ax1.set_title('Sales by Sub-Category', fontsize=16, fontweight='bold')
ax1.set_xlabel('Sub-Category', fontsize=12)
ax1.set_ylabel('Sales', fontsize=12)
ax1.set_xticklabels(sub_category_data.index, rotation=70)
ax1.set_facecolor('#FFCC99')
# Plot 2: Sales by Region
store_sorted = store.sort_values(by='Sales', ascending=False)
bars2 = ax2.bar(store_sorted['Region'], store_sorted['Sales'], color='#05eff7')
ax2.set_title('Sales by Region', fontsize=16, fontweight='bold')
ax2.set_xlabel('Region', fontsize=12)
ax2.set_ylabel('Sales', fontsize=12)
ax2.set_facecolor('#dfedd8')
# Plot 3: Sales by Category
bars3 = ax3.bar(store_sorted['Category'], store_sorted['Sales'], color='#f5baba')
ax3.set_title('Sales by Category', fontsize=16, fontweight='bold')
ax3.set_xlabel('Category', fontsize=12)
ax3.set_ylabel('Sales', fontsize=12)
ax3.set_facecolor('#F2F2F2')
# Plot 4: Sales by Ship Mode
bars4 = ax4.bar(store_sorted['Ship Mode'], store_sorted['Sales'], color='#2ecc71')
ax4.set_title('Sales by Ship Mode', fontsize=16, fontweight='bold')  # Fixed typo in the title
ax4.set_xlabel('Ship Mode', fontsize=12)
ax4.set_ylabel('Sales', fontsize=12)
ax4.set_facecolor('#ecf0f1')
# Adjust the layout to prevent overlapping of the subplots
fig.tight_layout()
# Display the plot
plt.show()
# Out:
# C:\Users\Uzzam\AppData\Local\Temp\ipykernel_9928\1983620686.py:9: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colormap = plt.cm.get_cmap('viridis')
# C:\Users\Uzzam\AppData\Local\Temp\ipykernel_9928\1983620686.py:16: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(sub_category_data.index, rotation=70)

# %% [markdown]
# <h3 style="background-color:#f5f5f5;font-family:newtimeroman;color:#0066cc;text-align:center">
# This analysis examines sales data across various product categories, regions, and ship modes. The bar chart visualization helps identify trends and patterns in sales performance.</h3>
#
# **Data:**
#
# * **Product Categories:** Technology, Office Supplies, Furniture
# * **Product Sub-Categories:** Bookcases, Chairs, Labels, Tables, Storage,
#        Furnishings, Art, Phones, Binders, Appliances, Paper,
#        Accessories, Envelopes, Fasteners, Supplies, Machines,
#         Copiers
# * **Regions:** South, Central, West, East
# * **Ship Modes:** Standard Class, First Class, Second Class, Same Day
#
# **Key Findings:**
#
# * A regional breakdown of sales reveals a pattern where sales are distributed unevenly, with the Southern region experiencing highest sales volume compared to Central and West regions. The Eastern region shows relatively lower sales compared to Central and West regions.
# * Sales data shows that the Standard class has the highest volume of sales, followed by First and Second classes. Same day sales have the lowest volume.
# * Analysis of sales figures indicates that technology items have a higher sales volume compared to office supplies and furniture.
# * Analysis of sales data indicates that phones and chairs share the highest sales volume among the analyzed categories. Storage, tables, binders, and other items show moderate sales, while arts supplies, envelopes, labels, and fasteners have lower sales in comparison.

# %% [markdown]
# <h3 style="background-color:#f5f5f5;font-family:newtimeroman;color:#0066cc;text-align:center">
# Profit Analysis by Category, Sub-Category, Region, and Ship Mode using line chart and bar chart.</h3>

# %%
# Calculate profit by Category
category_profit = store.groupby('Category')['Profit'].sum()
# Calculate profit by Sub-Category
sub_category_profit = store.groupby('Sub-Category')['Profit'].sum()
# Calculate profit by Region
region_profit = store.groupby('Region')['Profit'].sum()
# Calculate profit by Ship Mode
ship_mode_profit = store.groupby('Ship Mode')['Profit'].sum()
# Create the figure and subplots
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize=(15, 10), facecolor='lightgrey')
# Plot 1: Profit by Category
ax1.plot(category_profit.index, category_profit, marker='o', linewidth=2, markersize=8, color='blue')
ax1.fill_between(category_profit.index, category_profit, color='lightblue')
ax1.set_title('Profit by Category', fontsize=16, fontweight='bold')
ax1.set_xlabel('Category', fontsize=12)
ax1.set_ylabel('Profit', fontsize=12)
ax1.set_xticklabels(category_profit.index)
ax1.grid(True)
# Plot 2: Profit by Sub-Category
ax2.plot(sub_category_profit.index, sub_category_profit, marker='o', linewidth=2, markersize=8, color='green')
ax2.fill_between(sub_category_profit.index, sub_category_profit, color='lightgreen')
ax2.set_title('Profit by Sub-Category', fontsize=16, fontweight='bold')
ax2.set_xlabel('Sub-Category', fontsize=12)
ax2.set_ylabel('Profit', fontsize=12)
ax2.set_xticklabels(sub_category_profit.index, rotation=45)
ax2.grid(True)
# Plot 3: Profit by Region
ax3.plot(region_profit.index, region_profit, marker='o', linewidth=2, markersize=8, color='purple')
ax3.fill_between(region_profit.index, region_profit, color='#A569BD')
ax3.set_title('Profit by Region', fontsize=16, fontweight='bold')
ax3.set_xlabel('Region', fontsize=12)
ax3.set_ylabel('Profit', fontsize=12)
ax3.set_xticklabels(region_profit.index)
ax3.grid(True)
# Plot 4: Profit by Ship Mode
ax4.plot(ship_mode_profit.index, ship_mode_profit, marker='o', linewidth=2, markersize=8, color='#FF8C00')
ax4.fill_between(ship_mode_profit.index, ship_mode_profit, color='#FFCC99')
ax4.set_title('Profit by Ship Mode', fontsize=16, fontweight='bold')
ax4.set_xlabel('Ship Mode', fontsize=12)
ax4.set_ylabel('Profit', fontsize=12)
ax4.set_xticklabels(ship_mode_profit.index)
ax4.grid(True)
# Adjust the layout to prevent overlapping of the subplots
fig.tight_layout()
# Display the plot
plt.show()
# Out:
# C:\Users\Uzzam\AppData\Local\Temp\ipykernel_9928\3510630353.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(category_profit.index)
# C:\Users\Uzzam\AppData\Local\Temp\ipykernel_9928\3510630353.py:25: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(sub_category_profit.index, rotation=45)
# C:\Users\Uzzam\AppData\Local\Temp\ipykernel_9928\3510630353.py:33: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax3.set_xticklabels(region_profit.index)
# C:\Users\Uzzam\AppData\Local\Temp\ipykernel_9928\3510630353.py:41: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax4.set_xticklabels(ship_mode_profit.index)

# %%
# Create the figure and subplots
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize=(12, 10)) 
# Plot 1: Profit by Category
category_data = store.groupby('Category').sum()
category_data = category_data.sort_values('Profit', ascending=False)
colormap1 = plt.cm.get_cmap('viridis')
colormap1 = colormap1(np.linspace(0, 1, len(category_data)))
colormap1[:, 1] = np.clip(colormap1[:, 1] + 0.2, 0, 1)
bars1 = ax1.bar(category_data.index, category_data['Profit'], color=colormap1)
ax1.set_title('Profit by Category', fontsize=16, fontweight='bold')
ax1.set_xlabel('Category', fontsize=12)
ax1.set_ylabel('Profit', fontsize=12)
ax1.set_xticklabels(category_data.index)
ax1.set_facecolor('lightgray')
# Plot 2: Profit by Sub-Category
sub_category_data = store.groupby('Sub-Category').sum()
sub_category_data = sub_category_data.sort_values('Profit', ascending=False)
colormap2 = plt.cm.get_cmap('cividis')
colormap2 = colormap2(np.linspace(0, 1, len(sub_category_data)))
bars2 = ax2.bar(sub_category_data.index, sub_category_data['Profit'], color=colormap2)
ax2.set_title('Profit by Sub-Category', fontsize=16, fontweight='bold')
ax2.set_xlabel('Sub-Category', fontsize=12)
ax2.set_ylabel('Profit', fontsize=12)
ax2.set_xticklabels(sub_category_data.index, rotation=70)
ax2.set_facecolor('lightblue')
# Plot 3: Profit by Region
region_category_data = store.groupby('Region').sum()
region_category_data = region_category_data.sort_values('Profit', ascending=False)
colormap3 = plt.cm.get_cmap('turbo')
colormap3 = colormap3(np.linspace(0, 1, len(region_category_data)))
colormap3[:, 1] = np.clip(colormap3[:, 1] + 0.2, 0, 1)
bars3 = ax3.bar(region_category_data.index, region_category_data['Profit'], color=colormap3)
ax3.set_title('Profit by Region', fontsize=16, fontweight='bold')
ax3.set_xlabel('Region', fontsize=12)
ax3.set_ylabel('Profit', fontsize=12)
ax3.set_xticklabels(region_category_data.index)
ax3.set_facecolor('lightgreen')
# Plot 4: Profit by Ship Mode
mode_category_data = store.groupby('Ship Mode').sum()
mode_category_data = mode_category_data.sort_values('Profit', ascending=False)
colormap4 = plt.cm.get_cmap('rocket')
colormap4 = colormap4(np.linspace(0, 1, len(mode_category_data)))
colormap4[:, 1] = np.clip(colormap4[:, 1] + 0.2, 0, 1)
bars4 = ax4.bar(mode_category_data.index, mode_category_data['Profit'], color=colormap4)
ax4.set_title('Profit by Ship Mode', fontsize=16, fontweight='bold')
ax4.set_xlabel('Ship Mode', fontsize=12)
ax4.set_ylabel('Profit', fontsize=12)
ax4.set_xticklabels(mode_category_data.index)
ax4.set_facecolor('lightpink')
# Adjust the layout to prevent overlapping of the subplots
fig.tight_layout()
# Display the plot
plt.show()
# Out:
# C:\Users\Uzzam\AppData\Local\Temp\ipykernel_9928\3599618045.py:6: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colormap1 = plt.cm.get_cmap('viridis')
# C:\Users\Uzzam\AppData\Local\Temp\ipykernel_9928\3599618045.py:13: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(category_data.index)
# C:\Users\Uzzam\AppData\Local\Temp\ipykernel_9928\3599618045.py:18: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colormap2 = plt.cm.get_cmap('cividis')
# ...

# %% [markdown]
# <h3 style="background-color:#f5f5f5;font-family:newtimeroman;color:#0066cc;text-align:center">
# This analysis examines profit data across various product categories, regions, and ship modes. The bar chart and line chart visualization helps identify trends and patterns in profit.</h3>
#
# **Data:**
#
# * **Product Categories:** Technology, Office Supplies, Furniture
# * **Product Sub-Categories:** Bookcases, Chairs, Labels, Tables, Storage,
#        Furnishings, Art, Phones, Binders, Appliances, Paper,
#        Accessories, Envelopes, Fasteners, Supplies, Machines,
#         Copiers
# * **Regions:** South, Central, West, East
# * **Ship Modes:** Standard Class, First Class, Second Class, Same Day
#
# **Key Findings:**
#
# * The analysis of profit across product categories reveals that technology items yield the highest profit, office supplies generate moderate profit, and furniture yields the lowest profit.
# * Profit breakdown by region reveals an uneven distribution, with the West region exhibiting higher profit volumes compared to the South and East regions. In contrast, the Central region shows relatively lower profits compared to the South and East regions.
# * Profit data shows that the Standard class has the highest volume of profit, followed by Second and First classes. Same day Profit have the lowest volume.
# * The examination of profit data reveals that copiers and phones stand out as the categories with the highest profit volume. Following closely are accessories, papers, binders, and other items, demonstrating moderate profitability. Conversely, supplies, fasteners, and bookcases exhibit the lowest profit margins in comparison. Additionally, it appears that tables are associated with losses.

# %% [markdown]
# <h3 style="background-color:#f5f5f5;font-family:newtimeroman;color:#0066cc;text-align:center">
# Discount Analysis by Category, Sub-Category, Segment, and Ship Mode using bar chart.</h3>

# %%
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(12, 12))
# Plot 1: Discount by Category
discount_category_data = store.groupby('Category')['Discount'].mean().reset_index()
discount_category_data = discount_category_data.sort_values('Discount', ascending=False)
colormap1 = plt.cm.get_cmap('viridis')
colormap1 = colormap1(np.linspace(0, 1, len(discount_category_data)))
colormap1[:, 1] = np.clip(colormap1[:, 1] + 0.2, 0, 1)
bars1 = axs[0, 0].bar(range(len(discount_category_data)), discount_category_data['Discount'], color=colormap1)
axs[0, 0].set_title('Discount by category', fontsize=16, fontweight='bold')
axs[0, 0].set_xlabel('Category', fontsize=12)
axs[0, 0].set_ylabel('Discount', fontsize=12)
axs[0, 0].set_xticks(range(len(discount_category_data)))  # Set the x-axis tick positions
axs[0, 0].set_xticklabels(discount_category_data['Category'], rotation=0)  # Set the x-axis tick labels without rotation
axs[0, 0].set_facecolor('lightgray')
# Plot 2: Discount by Sub-Category
discount_sub_category_data = store.groupby('Sub-Category')['Discount'].mean().reset_index()
discount_sub_category_data = discount_sub_category_data.sort_values('Discount', ascending=False)
colormap2 = plt.cm.get_cmap('viridis')
colormap2 = colormap2(np.linspace(0, 1, len(discount_sub_category_data)))
colormap2[:, 1] = np.clip(colormap2[:, 1] + 0.2, 0, 1)
bars2 = axs[0, 1].bar(range(len(discount_sub_category_data)), discount_sub_category_data['Discount'], color=colormap2)
axs[0, 1].set_title('Discount by sub-category', fontsize=16, fontweight='bold')
axs[0, 1].set_xlabel('Sub-Category', fontsize=12)
axs[0, 1].set_ylabel('Discount', fontsize=12)
axs[0, 1].set_xticks(range(len(discount_sub_category_data)))  # Set the x-axis tick positions
axs[0, 1].set_xticklabels(discount_sub_category_data['Sub-Category'], rotation=45)  # Set the x-axis tick labels with rotation
axs[0, 1].set_facecolor('lightgray')
# Plot 3: Discount by Ship Mode
discount_ship_data = store.groupby('Ship Mode')['Discount'].mean().reset_index()
discount_ship_data = discount_ship_data.sort_values('Discount', ascending=False)
colormap3 = plt.cm.get_cmap('viridis')
colormap3 = colormap3(np.linspace(0, 1, len(discount_ship_data)))
colormap3[:, 1] = np.clip(colormap3[:, 1] + 0.2, 0, 1)
bars3 = axs[1, 0].bar(range(len(discount_ship_data)), discount_ship_data['Discount'], color=colormap3)
axs[1, 0].set_title('Discount by Ship Mode', fontsize=16, fontweight='bold')
axs[1, 0].set_xlabel('Ship Mode', fontsize=12)
axs[1, 0].set_ylabel('Discount', fontsize=12)
axs[1, 0].set_xticks(range(len(discount_ship_data)))  # Set the x-axis tick positions
axs[1, 0].set_xticklabels(discount_ship_data['Ship Mode'], rotation=0)  # Set the x-axis tick labels without rotation
axs[1, 0].set_facecolor('lightgray')
# Plot 4: Discount by Segment
discount_segment_data = store.groupby('Segment')['Discount'].mean().reset_index()
discount_segment_data = discount_segment_data.sort_values('Discount', ascending=False)
colormap4 = plt.cm.get_cmap('viridis')
colormap4 = colormap4(np.linspace(0, 1, len(discount_segment_data)))
colormap4[:, 1] = np.clip(colormap4[:, 1] + 0.2, 0, 1)
bars4 = axs[1, 1].bar(range(len(discount_segment_data)), discount_segment_data['Discount'], color=colormap4)
axs[1, 1].set_title('Discount by Segment', fontsize=16, fontweight='bold')
axs[1, 1].set_xlabel('Segment', fontsize=12)
axs[1, 1].set_ylabel('Discount', fontsize=12)
axs[1, 1].set_xticks(range(len(discount_segment_data)))  # Set the x-axis tick positions
axs[1, 1].set_xticklabels(discount_segment_data['Segment'], rotation=0)  # Set the x-axis tick labels without rotation
axs[1, 1].set_facecolor('lightgray')
# Adjust the layout to prevent overlapping of the subplots
fig.tight_layout()
# Display the plot
plt.show()
# Out:
# C:\Users\Uzzam\AppData\Local\Temp\ipykernel_9928\869455606.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colormap1 = plt.cm.get_cmap('viridis')
# C:\Users\Uzzam\AppData\Local\Temp\ipykernel_9928\869455606.py:18: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colormap2 = plt.cm.get_cmap('viridis')
# C:\Users\Uzzam\AppData\Local\Temp\ipykernel_9928\869455606.py:31: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colormap3 = plt.cm.get_cmap('viridis')
# ...

# %% [markdown]
# <h3 style="background-color:#f5f5f5;font-family:newtimeroman;color:#0066cc;text-align:center">
# This analysis examines disounts data across various product categories, segments, and ship modes. The bar chart visualization helps identify trends and patterns in discounts.</h3>
#
# **Data:**
#
# * **Product Categories:** Technology, Office Supplies, Furniture
# * **Product Sub-Categories:** Bookcases, Chairs, Labels, Tables, Storage,
#        Furnishings, Art, Phones, Binders, Appliances, Paper,
#        Accessories, Envelopes, Fasteners, Supplies, Machines,
#         Copiers
# * **Segment:** Consumer, Corporate, Home Office
# * **Ship Modes:** Standard Class, First Class, Second Class, Same Day
#
# **Key Findings:**
#
# * The examination of discounts across product categories demonstrates that furniture offers the highest discount, office supplies provide a moderate discount, and technology products offer the lowest discount.
# * It appears that both the Corporate and Consumer segments offer nearly identical discounts, while the Head Office segment provides slightly lower discounts compared to them.
# * Discount data shows that the First class has the highest volume of profit, followed by Standard Class and Same Day. Second Class have the lowest volume of discounts.
# * The examination of discount data reveals that binders, machines and tables stand out as the categories with the highest profit volume. Following closely are book cases, chairs, appliances and other items, demonstrating moderate discount. Conversely, art, storage and labels exhibit the lowest discount margins in comparison.

# %% [markdown]
# <h3 style="background-color:#f5f5f5;font-family:newtimeroman;color:#0066cc;text-align:center">
# Profit and Sales by segment using bar chart.</h3>

# %%
# Create the figure and subplots
fig, ((ax1, ax2)) = plt.subplots(nrows=1, ncols=2, figsize=(10, 5)) 
# Plot 1: Profit by Segment
segment_profit_data = store.groupby('Segment').sum()
segment_profit_data= segment_profit_data.sort_values('Profit', ascending=False)
colormap1 = plt.cm.get_cmap('viridis')
colormap1 = colormap1(np.linspace(0, 1, len(segment_profit_data )))
colormap1[:, 1] = np.clip(colormap1[:, 1] + 0.2, 0, 1)
bars1 = ax1.bar(segment_profit_data.index, segment_profit_data['Profit'], color=colormap1)
ax1.set_title('Profit by Segment', fontsize=16, fontweight='bold')
ax1.set_xlabel('Segment', fontsize=12)
ax1.set_ylabel('Profit', fontsize=12)
ax1.set_xticklabels(segment_profit_data.index)
ax1.set_facecolor('lightgray')
# Plot 2: Sales by Sub-Category
segment_sales_data = store.groupby('Segment').sum()
segment_sales_data = segment_sales_data.sort_values('Sales', ascending=False)
colormap2 = plt.cm.get_cmap('cividis')
colormap2 = colormap2(np.linspace(0, 1, len(segment_sales_data)))
bars2 = ax2.bar(segment_sales_data.index, segment_sales_data['Sales'], color=colormap2)
ax2.set_title('Sales by Segment', fontsize=16, fontweight='bold')
ax2.set_xlabel('Segment', fontsize=12)
ax2.set_ylabel('Sales', fontsize=12)
ax2.set_xticklabels(segment_sales_data.index, rotation=0)
ax2.set_facecolor('lightblue')
# Adjust the layout to prevent overlapping of the subplots
fig.tight_layout()
# Display the plot
plt.show()
# Out:
# C:\Users\Uzzam\AppData\Local\Temp\ipykernel_9928\1898270351.py:6: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colormap1 = plt.cm.get_cmap('viridis')
# C:\Users\Uzzam\AppData\Local\Temp\ipykernel_9928\1898270351.py:13: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(segment_profit_data.index)
# C:\Users\Uzzam\AppData\Local\Temp\ipykernel_9928\1898270351.py:18: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colormap2 = plt.cm.get_cmap('cividis')
# ...

# %% [markdown]
# <h3 style="background-color:#f5f5f5;font-family:newtimeroman;color:#0066cc;text-align:center">
# This analysis examines profit and sales data across various segments. The bar chart visualization helps identify trends and patterns.</h3>
#
# **Data:**
# * **Segment:** Consumer, Corporate, Home Office
#
# **Key Findings:**
#
# * The examination of profit across segments demonstrates that consumer offers the highest profit, corporate provide a moderate profit, and Home Office offer the lowest profit.
# * The examination of sales across segments demonstrates that consumer offers the highest sales, corporate provide a moderate sales, and Home Office offer the lowest sales.
